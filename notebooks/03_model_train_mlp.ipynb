# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os

# Agregar la carpeta raíz del proyecto al path
sys.path.append(os.path.dirname(os.getcwd()))

# %%
import pandas as pd
print("Cargando datos procesados...")
train_df = pd.read_csv('../temp/train_processed.csv')
test_df = pd.read_csv('../temp/test_processed.csv')

# 2. Separar X e y
X_train = train_df.drop(columns=['popularity'])
y_train = train_df['popularity']

X_test = test_df.drop(columns=['popularity'])
y_test = test_df['popularity']

print(f"X_train: {X_train.shape}")
print(f"X_test: {X_test.shape}")
# Out:
# Cargando datos procesados...
# X_train: (333345, 43)
# X_test: (83336, 43)

# %%
from helpers.trainer import ModelTrainer
trainer = ModelTrainer(
    X_train=X_train,
    X_test=X_test,
    y_train=y_train,
    y_test=y_test,
    target_col='popularity'
)
# Out:
# ✓ ModelTrainer inicializado - Target: popularity
#   Train: 333,345 muestras, 43 features
#   Test: 83,336 muestras
#   Target range: [0.0, 96.0]
#   Target mean: 29.3 ± 15.8

# %%
custom_grid = {
    'n_estimators': [200, 300],
    'learning_rate': [0.05, 0.1],
    'max_depth': [5, 7]
} # Pueden configurar esta grid como deseen o quitarla para usar la por defecto

# %%
trainer.train_model(
    model_name='mlp',
    cv=5,
    param_grid=None # Pueden pasar custom_grid o None para usar la grid por defecto
)
# Out:
# ================================================================================
# ENTRENANDO: MLP
# ================================================================================
# Grid de búsqueda:
#   hidden_layer_sizes: [(64,), (128,), (128, 64)]
#   activation: ['relu']
#   alpha: [0.001, 0.01]
#   learning_rate: ['adaptive']
#   max_iter: [500]
#
#  Buscando mejores hiperparámetros con 5-Fold CV...
#   Total combinaciones: 6
#
#   [1/6] Probando: {'hidden_layer_sizes': (64,), 'activation': 'relu', 'alpha': 0.001, 'learning_rate': 'adaptive', 'max_iter': 500}

# %%
print(trainer.results.keys())  #Debe incluir el modelo entrenado
# Out:
# dict_keys(['lightgbm'])

# %%
results = trainer.results['mlp'] #No da error si el modelo fue entrenado correctamente
print(f"mlp CV MSE: {results['cv_score']:.4f}")
print(f"mlp Test R²: {results['test_metrics']['r2']:.4f}")
# Out:
# XGBoost CV MSE: 152.2869
# XGBoost Test R²: 0.3848

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os

# Agregar la carpeta raíz del proyecto al path
sys.path.append(os.path.dirname(os.getcwd()))

# %%
import pandas as pd
print("Cargando datos procesados...")
train_df = pd.read_csv('../temp/train_processed_ordinal.csv')
test_df = pd.read_csv('../temp/test_processed_ordinal.csv')

# 2. Separar X e y
X_train = train_df.drop(columns=['popularity'])
y_train = train_df['popularity']

X_test = test_df.drop(columns=['popularity'])
y_test = test_df['popularity']

print(f"X_train: {X_train.shape}")
print(f"X_test: {X_test.shape}")
# Out:
# Cargando datos procesados...
# X_train: (564787, 14)
# X_test: (141198, 14)

# %%
from helpers.trainer import ModelTrainer
trainer = ModelTrainer(
    X_train=X_train,
    X_test=X_test,
    y_train=y_train,
    y_test=y_test,
    target_col='popularity'
)
# Out:
# ✓ ModelTrainer inicializado - Target: popularity
#   Train: 564,787 muestras, 14 features
#   Test: 141,198 muestras
#   Target range: [11.0, 96.0]
#   Target mean: 28.0 ± 13.1

# %%
custom_grid = {
            'n_estimators': [200, 300],
            'learning_rate': [0.01, 0.05],
            'max_depth': [7, 10],
            'num_leaves': [50],
            'min_child_samples': [20, 30],
            'subsample': [0.8, 1.0],
            'colsample_bytree': [0.8, 1.0]
} # Pueden configurar esta grid como deseen o quitarla para usar la por defecto

# %%
trainer.train_model(
    model_name='lightgbm',
    cv=5,
    param_grid=custom_grid, # Pueden pasar custom_grid o None para usar la grid por defecto
)
# Out:
# ================================================================================
# ENTRENANDO: LIGHTGBM
# ================================================================================
# Grid de búsqueda:
#   n_estimators: [200, 300]
#   learning_rate: [0.01, 0.05]
#   max_depth: [7, 10]
#   num_leaves: [50]
#   min_child_samples: [20, 30]
#   subsample: [0.8, 1.0]
#   colsample_bytree: [0.8, 1.0]
#
#  Buscando mejores hiperparámetros con 5-Fold CV...
#   Total combinaciones: 64
#
#   [1/64] Probando: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 0.8, 'colsample_bytree': 0.8}
#     MSE CV: 127.9526 (±0.5184)
#     ✓ Nuevo mejor score: 127.9526
#
#   [2/64] Probando: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 0.8, 'colsample_bytree': 1.0}
#     MSE CV: 128.9359 (±0.3841)
#
#   [3/64] Probando: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 1.0, 'colsample_bytree': 0.8}
#     MSE CV: 127.9526 (±0.5184)
#
#   [4/64] Probando: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 1.0, 'colsample_bytree': 1.0}
#     MSE CV: 128.9359 (±0.3841)
#
#   [5/64] Probando: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 0.8, 'colsample_bytree': 0.8}
#     MSE CV: 127.9632 (±0.5253)
#
#   [6/64] Probando: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 0.8, 'colsample_bytree': 1.0}
#     MSE CV: 128.9207 (±0.3938)
#
#   [7/64] Probando: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 1.0, 'colsample_bytree': 0.8}
#     MSE CV: 127.9632 (±0.5253)
#
#   [8/64] Probando: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 1.0, 'colsample_bytree': 1.0}
#     MSE CV: 128.9207 (±0.3938)
#
#   [9/64] Probando: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 0.8, 'colsample_bytree': 0.8}
#     MSE CV: 124.6979 (±0.3196)
#     ✓ Nuevo mejor score: 124.6979
#
#   [10/64] Probando: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 0.8, 'colsample_bytree': 1.0}
#     MSE CV: 125.6187 (±0.4699)
# Checkpoint guardado: ../temp/checkpoints/lightgbm_checkpoint_10.joblib
#
#   [11/64] Probando: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 1.0, 'colsample_bytree': 0.8}
#     MSE CV: 124.6979 (±0.3196)
#
#   [12/64] Probando: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 1.0, 'colsample_bytree': 1.0}
#     MSE CV: 125.6187 (±0.4699)
#
#   [13/64] Probando: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 0.8, 'colsample_bytree': 0.8}
#     MSE CV: 124.6714 (±0.3696)
#     ✓ Nuevo mejor score: 124.6714
#
#   [14/64] Probando: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 0.8, 'colsample_bytree': 1.0}
#     MSE CV: 125.6190 (±0.4703)
#
#   [15/64] Probando: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 1.0, 'colsample_bytree': 0.8}
#     MSE CV: 124.6714 (±0.3696)
#
#   [16/64] Probando: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 1.0, 'colsample_bytree': 1.0}
#     MSE CV: 125.6190 (±0.4703)
#
#   [17/64] Probando: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 0.8, 'colsample_bytree': 0.8}
#     MSE CV: 109.8353 (±0.3291)
#     ✓ Nuevo mejor score: 109.8353
#
#   [18/64] Probando: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 0.8, 'colsample_bytree': 1.0}
#     MSE CV: 110.0129 (±0.3162)
#
#   [19/64] Probando: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 1.0, 'colsample_bytree': 0.8}
#     MSE CV: 109.8353 (±0.3291)
#
#   [20/64] Probando: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 1.0, 'colsample_bytree': 1.0}
#     MSE CV: 110.0129 (±0.3162)
# Checkpoint guardado: ../temp/checkpoints/lightgbm_checkpoint_20.joblib
#
#   [21/64] Probando: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 0.8, 'colsample_bytree': 0.8}
#     MSE CV: 109.8394 (±0.2944)
#
#   [22/64] Probando: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 0.8, 'colsample_bytree': 1.0}
#     MSE CV: 110.0604 (±0.2202)
#
#   [23/64] Probando: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 1.0, 'colsample_bytree': 0.8}
#     MSE CV: 109.8394 (±0.2944)
#
#   [24/64] Probando: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 1.0, 'colsample_bytree': 1.0}
#     MSE CV: 110.0604 (±0.2202)
#
#   [25/64] Probando: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 0.8, 'colsample_bytree': 0.8}
#     MSE CV: 108.5934 (±0.2374)
#     ✓ Nuevo mejor score: 108.5934
#
#   [26/64] Probando: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 0.8, 'colsample_bytree': 1.0}
#     MSE CV: 108.6629 (±0.2090)
#
#   [27/64] Probando: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 1.0, 'colsample_bytree': 0.8}
#     MSE CV: 108.5934 (±0.2374)
#
#   [28/64] Probando: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 1.0, 'colsample_bytree': 1.0}
#     MSE CV: 108.6629 (±0.2090)
#
#   [29/64] Probando: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 0.8, 'colsample_bytree': 0.8}
#     MSE CV: 108.5350 (±0.2108)
#     ✓ Nuevo mejor score: 108.5350
#
#   [30/64] Probando: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 0.8, 'colsample_bytree': 1.0}
#     MSE CV: 108.6829 (±0.3302)
# Checkpoint guardado: ../temp/checkpoints/lightgbm_checkpoint_30.joblib
#
#   [31/64] Probando: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 1.0, 'colsample_bytree': 0.8}
#     MSE CV: 108.5350 (±0.2108)
#
#   [32/64] Probando: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 1.0, 'colsample_bytree': 1.0}
#     MSE CV: 108.6829 (±0.3302)
#
#   [33/64] Probando: {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 0.8, 'colsample_bytree': 0.8}
#     MSE CV: 121.6130 (±0.4806)
#
#   [34/64] Probando: {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 0.8, 'colsample_bytree': 1.0}
#     MSE CV: 122.6969 (±0.1802)
#
#   [35/64] Probando: {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 1.0, 'colsample_bytree': 0.8}
#     MSE CV: 121.6130 (±0.4806)
#
#   [36/64] Probando: {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 1.0, 'colsample_bytree': 1.0}
#     MSE CV: 122.6969 (±0.1802)
#
#   [37/64] Probando: {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 0.8, 'colsample_bytree': 0.8}
#     MSE CV: 121.5611 (±0.4790)
#
#   [38/64] Probando: {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 0.8, 'colsample_bytree': 1.0}
#     MSE CV: 122.7081 (±0.1978)
#
#   [39/64] Probando: {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 1.0, 'colsample_bytree': 0.8}
#     MSE CV: 121.5611 (±0.4790)
#
#   [40/64] Probando: {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 1.0, 'colsample_bytree': 1.0}
#     MSE CV: 122.7081 (±0.1978)
# Checkpoint guardado: ../temp/checkpoints/lightgbm_checkpoint_40.joblib
#
#   [41/64] Probando: {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 0.8, 'colsample_bytree': 0.8}
#     MSE CV: 118.8345 (±0.3843)
#
#   [42/64] Probando: {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 0.8, 'colsample_bytree': 1.0}
#     MSE CV: 119.6703 (±0.3552)
#
#   [43/64] Probando: {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 1.0, 'colsample_bytree': 0.8}
#     MSE CV: 118.8345 (±0.3843)
#
#   [44/64] Probando: {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 1.0, 'colsample_bytree': 1.0}
#     MSE CV: 119.6703 (±0.3552)
#
#   [45/64] Probando: {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 0.8, 'colsample_bytree': 0.8}
#     MSE CV: 118.8195 (±0.4589)
#
#   [46/64] Probando: {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 0.8, 'colsample_bytree': 1.0}
#     MSE CV: 119.6950 (±0.3951)
#
#   [47/64] Probando: {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 1.0, 'colsample_bytree': 0.8}
#     MSE CV: 118.8195 (±0.4589)
#
#   [48/64] Probando: {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 1.0, 'colsample_bytree': 1.0}
#     MSE CV: 119.6950 (±0.3951)
#
#   [49/64] Probando: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 0.8, 'colsample_bytree': 0.8}
#     MSE CV: 107.6659 (±0.1994)
#     ✓ Nuevo mejor score: 107.6659
#
#   [50/64] Probando: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 0.8, 'colsample_bytree': 1.0}
#     MSE CV: 107.8790 (±0.1196)
# Checkpoint guardado: ../temp/checkpoints/lightgbm_checkpoint_50.joblib
#
#   [51/64] Probando: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 1.0, 'colsample_bytree': 0.8}
#     MSE CV: 107.6659 (±0.1994)
#
#   [52/64] Probando: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 1.0, 'colsample_bytree': 1.0}
#     MSE CV: 107.8790 (±0.1196)
#
#   [53/64] Probando: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 0.8, 'colsample_bytree': 0.8}
#     MSE CV: 107.7421 (±0.2378)
#
#   [54/64] Probando: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 0.8, 'colsample_bytree': 1.0}
#     MSE CV: 107.9031 (±0.2399)
#
#   [55/64] Probando: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 1.0, 'colsample_bytree': 0.8}
#     MSE CV: 107.7421 (±0.2378)
#
#   [56/64] Probando: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 7, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 1.0, 'colsample_bytree': 1.0}
#     MSE CV: 107.9031 (±0.2399)
#
#   [57/64] Probando: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 0.8, 'colsample_bytree': 0.8}
#     MSE CV: 107.1515 (±0.1888)
#     ✓ Nuevo mejor score: 107.1515
#
#   [58/64] Probando: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 0.8, 'colsample_bytree': 1.0}
#     MSE CV: 107.3218 (±0.1978)
#
#   [59/64] Probando: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 1.0, 'colsample_bytree': 0.8}
#     MSE CV: 107.1515 (±0.1888)
#
#   [60/64] Probando: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 20, 'subsample': 1.0, 'colsample_bytree': 1.0}
#     MSE CV: 107.3218 (±0.1978)
# Checkpoint guardado: ../temp/checkpoints/lightgbm_checkpoint_60.joblib
#
#   [61/64] Probando: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 0.8, 'colsample_bytree': 0.8}
#     MSE CV: 107.1389 (±0.2012)
#     ✓ Nuevo mejor score: 107.1389
#
#   [62/64] Probando: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 0.8, 'colsample_bytree': 1.0}
#     MSE CV: 107.2736 (±0.2741)
#
#   [63/64] Probando: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 1.0, 'colsample_bytree': 0.8}
#     MSE CV: 107.1389 (±0.2012)
#
#   [64/64] Probando: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 1.0, 'colsample_bytree': 1.0}
#     MSE CV: 107.2736 (±0.2741)
#
# ✓ Mejores parámetros encontrados: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 10, 'num_leaves': 50, 'min_child_samples': 30, 'subsample': 0.8, 'colsample_bytree': 0.8}
# ✓ Mejor MSE en CV: 107.1389
#
#  Reentrenando en train completo (564,787 muestras)...
# ✓ Reentrenamiento completado
#
# Métricas en Train Set:
#   MSE: 105.1055
#   RMSE: 10.2521
#   MAE: 8.1343
#   R²: 0.3890
#
# Métricas en Test Set (evaluación final):
#   MSE: 106.7625
#   RMSE: 10.3326
#   MAE: 8.2016
#   R²: 0.3788
#
# Tiempo total: 2103.8s
# {'model_name': 'lightgbm',
#  'best_params': {'n_estimators': 300,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'num_leaves': 50,
#   'min_child_samples': 30,
#   'subsample': 0.8,
#   'colsample_bytree': 0.8},
#  'cv_score': np.float64(107.13892065436237),
#  'train_metrics': {'mse': 105.10552569717535,
#   'rmse': np.float64(10.25209859966121),
#   'mae': 8.134306087294632,
#   'r2': 0.3890444899195359},
#  'test_metrics': {'mse': 106.7624659089692,
#   'rmse': np.float64(10.332592409892554),
#   'mae': 8.201571196745286,
#   'r2': 0.37880331703715775},
#  'training_time': 2103.759105,
#  'model': LGBMRegressor(colsample_bytree=0.8, learning_rate=0.05, max_depth=10,
#                min_child_samples=30, n_estimators=300, n_jobs=-1, num_leaves=50,
#                random_state=42, subsample=0.8, verbose=-1)}

# %%
print(trainer.results.keys())  #Debe incluir el modelo entrenado
# Out:
# dict_keys(['lightgbm'])

# %%
results = trainer.results['lightgbm'] #No da error si el modelo fue entrenado correctamente
print(f"LightGBM CV MSE: {results['cv_score']:.4f}")
print(f"LightGBM Test R²: {results['test_metrics']['r2']:.4f}")
# Out:
# LightGBM CV MSE: 107.1389
# LightGBM Test R²: 0.3788

# %%
trainer.save_model(model_name='lightgbm', path='../models/lightgbm_model_ordinal.joblib')
# Out:
# ✓ Modelo guardado: ../models/lightgbm_model_ordinal.joblib
# ✓ Metadata guardada: ../models/lightgbm_model_ordinal_metadata.joblib

# %%
from helpers.trainer import load_model
# Para cargar el modelo guardado posteriormente
loaded_model,metadata = load_model(path='../models/lightgbm_model_ordinal.joblib')

loaded_model
# Out:
# ✓ Modelo: lightgbm
#   CV MSE: 107.1389
#   Test R²: 0.3788
#   Test RMSE: 10.3326
# LGBMRegressor(colsample_bytree=0.8, learning_rate=0.05, max_depth=10,
#               min_child_samples=30, n_estimators=300, n_jobs=-1, num_leaves=50,
#               random_state=42, subsample=0.8, verbose=-1)

# %%
#Test predicción para un dato
i=15
sample = X_test.iloc[[i]]  # Tomar la primera fila como ejemplo
prediction = loaded_model.predict(sample)
print(f"Predicción para el dato de test: {prediction[0]:.4f}")
print(f"Valor real: {y_test.iloc[i]:.4f}")
# Out:
# Predicción para el dato de test: 31.2583
# Valor real: 25.0000

# %%
#Dataframe de prediccion y reales
test_predictions = loaded_model.predict(X_test)
#Añadir el error RMSE punto a punto
rmse_pointwise = ((y_test - test_predictions) ** 2) ** 0.5

results_df = pd.DataFrame({
    'Actual': y_test,
    'Predicted': test_predictions,
    'RMSE': rmse_pointwise
})
results_df.head(10)

#mostrar dato con mayor error
max_error_row = results_df.loc[results_df['RMSE'].idxmax()]
print("Dato con mayor error de predicción:")
print(max_error_row)
#características del dato con mayor error
features_max_error = X_test.loc[results_df['RMSE'].idxmax()]
print("Características del dato con mayor error:")
print(features_max_error)

#mostrar dato con menor error
min_error_row = results_df.loc[results_df['RMSE'].idxmin()]
print("Dato con menor error de predicción:")
print(min_error_row)
#características del dato con menor error
features_min_error = X_test.loc[results_df['RMSE'].idxmin()]
print("Características del dato con menor error:")
print(features_min_error)
# Out:
# Dato con mayor error de predicción:
# Actual       89.000000
# Predicted    32.636606
# RMSE         56.363394
# Name: 133044, dtype: float64
# Características del dato con mayor error:
# acousticness         0.487310
# danceability        -0.137497
# energy              -1.202293
# instrumentalness    -0.629710
# key                  1.044597
# liveness            -0.011191
# loudness            -0.545201
# mode                 0.768310
# speechiness         -0.523834
# tempo                0.882651
# time_signature      -1.982617
# valence             -0.703165
# duration_ms         -0.459769
# genre               27.000000
# Name: 133044, dtype: float64
# Dato con menor error de predicción:
# Actual       27.000000
# Predicted    27.000249
# RMSE          0.000249
# Name: 127990, dtype: float64
# Características del dato con menor error:
# acousticness        0.872276
# danceability       -0.165075
# energy             -1.056309
# instrumentalness   -0.635218
# key                 0.482369
# liveness           -0.634693
# loudness            0.330740
# mode                0.768310
# speechiness        -0.514349
# tempo              -0.151568
# time_signature      2.458561
# valence            -0.565713
# duration_ms        -0.080778
# genre               0.000000
# Name: 127990, dtype: float64
